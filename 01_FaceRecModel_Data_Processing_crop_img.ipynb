# %%
import numpy as np
import cv2 
from glob import glob
import matplotlib.pyplot as plt

# %%
femalepath = glob('./data/female/*.jpg')
malepath = glob('./data/male/*.jpg')

# %%
print('length of female folder:',len(femalepath))
print('length of female folder:',len(malepath))
# Out:
# length of female folder: 4762
# length of female folder: 5399

# %%
#step-1: read  and convert image to rgb
img = cv2.imread(femalepath[0]) #read image 
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #convert image to rgb

#step-2: apply haar cascade classifier,  haarcascade_frontalface_default.xml
haar = cv2.CascadeClassifier('./model/haarcascade_frontalface_default.xml')
gray = cv2.cvtColor(img_rgb,cv2.COLOR_BGR2GRAY)
faces_list = haar.detectMultiScale(gray,1.5,5)
print(faces_list)
for x,y,w,h in faces_list:
    cv2.rectangle(img_rgb,(x,y),(x+w,y+h),(0,255,0),2)
    ### Step -3: crop Face 
    roi = img_rgb[y:y+h,x:x+w]
    
    plt.imshow(roi)
    plt.axis('off')
    plt.show()
# Out:
# [[ 80  86 273 273]]

# %%
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# %%
""" Implement above process to all images

**Crop all `female` Images**

# %%
#loding model for classifier
haar = cv2.CascadeClassifier('./model/haarcascade_frontalface_default.xml')

# %%
for i in range(len(femalepath)):
    try:
            
        ### Step -1 Read Image and Convert to RGB
        img = cv2.imread(femalepath[i]) # read image in BGR
        img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) # this step will convert image from BGR to RGB

        ### Step -2: Apply Haar Cascade Classifier
        gray = cv2.cvtColor(img_rgb,cv2.COLOR_BGR2GRAY)
        faces_list = haar.detectMultiScale(gray,1.5,5)
        for x,y,w,h in faces_list:
            ### Step -3: crop Face 
            roi = img[y:y+h,x:x+w]
            ### Step -4: Save Image
            cv2.imwrite(f'./crop_data/female/female_{i}.jpg',roi)
            print('Image Sucessfully processed')
    except:
        print('Unable to Process the image')
# Out:
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# ...

# %%
# croping all male images and locating to directory

# %%
for i in range(len(malepath)):
    try:
            
        ### Step -1 Read Image and Convert to RGB
        img = cv2.imread(malepath[i]) # read image in BGR
        img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) # this step will convert image from BGR to RGB

        ### Step -2: Apply Haar Cascade Classifier
        gray = cv2.cvtColor(img_rgb,cv2.COLOR_BGR2GRAY)
        faces_list = haar.detectMultiScale(gray,1.5,5)
        for x,y,w,h in faces_list:
            ### Step -3: crop Face 
            roi = img[y:y+h,x:x+w]
            ### Step -4: Save Image
            cv2.imwrite(f'./crop_data/male/male_{i}.jpg',roi)
            print('Image Sucessfully processed')
    except:
        print('Unable to Process the image')
# Out:
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# Image Sucessfully processed
# ...
